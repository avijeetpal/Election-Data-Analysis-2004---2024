# %% [markdown]
# #### Read Data

# %%
# import required Libraries

import pandas as pd

# %%
# read dataset 1,2,3

data1 = pd.read_csv(r'Cleaned Dataset/dataset1.csv')
data2 = pd.read_csv(r'Cleaned Dataset/dataset2.csv')
data3 = pd.read_csv(r'Cleaned Dataset/dataset3.csv')

# %%
print("Electrol and Voter Dataset")
print(data1.head())
# Out:
# Electrol and Voter Dataset
#    Year           State  Male_Electors  Female_Electors  Total_Electors  \
# 0  2004  ANDHRA PRADESH         456636           501990          958626
# 1  2004  ANDHRA PRADESH         432612           463724          896336
# 2  2004  ANDHRA PRADESH         474981           501031          976012
# 3  2004  ANDHRA PRADESH         752037           763537         1515574
# 4  2004  ANDHRA PRADESH         584519           608778         1193297
#
#    Male_Voters  Female_Voters  Total_Voters
# 0       350869         372144        723013
# 1       331841         328371        660212
# 2       372376         373141        745517
# 3       499805         465930        965735
# 4       428618         394242        822860

# %% [markdown]
# #### `EDA Conclusion` of dataset 1
#
# 1. Voter Turnout analysis (male vs female, year wise %)
#
# 2. Increment or decrement of voter turnout per session
#
# 3. Use Line chart for turnout trend (not histogram)
#
# 4. Pie chart optional (less useful for time-series)

# %%
print("Male vs Female Candidate")
print(data2.head())
# Out:
# Male vs Female Candidate
#    Year               State  Total_Seats  Male_Candidate  Female_Candidate  \
# 0   2004     Andhra Pradesh           42             258                21
# 1   2004  ARUNACHAL PRADESH            2              13                 0
# 2   2004              Assam           14             110                 6
# 3   2004              Bihar           40             448                14
# 4   2004                Goa            2              15                 1
#
#    Male_Winner  Female_Winner
# 0           39              3
# 1            2              0
# 2           14              0
# 3           37              3
# 4            2              0

# %% [markdown]
# #### `EDA Conclusion` Dataset 2
#
# 1. Compare Male vs Female Candidate Participate in an election
#
# 2. Compare Elected Male vs Elected Female in an election
#
# 3. Used Pie chart

# %%
print("Election Expense Data")
print(data3.head())
# Out:
# Election Expense Data
#    Year  Seats  Total_Electors  Candidate_expen_per_Seat  \
# 0  2004    543       671487930                 2500000.0
# 1  2009    543       716985101                 4000000.0
# 2  2014    543       834054287                 7000000.0
# 3  2019    543       911950734                 7000000.0
# 4  2024    543       977965560                 8500000.0
#
#    Max_Legal_Candidate_Expense  Legal_Cost_per_Voter  Gove_Expense  \
# 0                   1357500000                  2.02   10160869000
# 1                   2172000000                  3.03   11143845000
# 2                   3801000000                  4.56   38703456024
# 3                   3801000000                  4.17   70000000000
# 4                   4615500000                  4.72  140000000000
#
#    Legal_Cost_per_Voter.1      Election_Type  Data_Type
# 0                   15.13         Lok Sabha   Estimated
# 1                   15.54         Lok Sabha   Estimated
# ...

# %% [markdown]
# #### `EDA Conclusion` Dataset 3
#
# 1. Total Expense to conduct election
#
# 2. Avg legal cost per voter
